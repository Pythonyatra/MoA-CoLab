# %% [markdown]
# <a href="https://colab.research.google.com/github/Pythonyatra/MoA-CoLab/blob/master/DataExtractionKaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio

import random
import time

# %%
train = pd.read_csv('./datasets/train_features.csv')
test = pd.read_csv('./datasets/test_features.csv')

# %%
print(train.shape)
print(test.shape)
# Out:
# (23814, 876)
# (3982, 876)

# %%
train.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  4.0620 -0.8095  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  1.4180 -0.8244  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
train.describe()
# Out:
#             cp_time           g-0           g-1           g-2           g-3  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      48.020156      0.248366     -0.095684      0.152253      0.081971
# std       19.402807      1.393399      0.812363      1.035731      0.950012
# min       24.000000     -5.513000     -5.737000     -9.104000     -5.998000
# 25%       24.000000     -0.473075     -0.562200     -0.437750     -0.429575
# 50%       48.000000     -0.008850     -0.046600      0.075200      0.008050
# 75%       72.000000      0.525700      0.403075      0.663925      0.463400
# max       72.000000     10.000000      5.039000      8.257000     10.000000
#
#                 g-4           g-5           g-6           g-7           g-8  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.057347     -0.138836      0.035961     -0.202651     -0.190083
# ...

# %%
test.head()
# Out:
#          sig_id      cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_0004d9e33       trt_cp       24      D1 -0.5458  0.1306 -0.5135  0.4408
# 1  id_001897cda       trt_cp       72      D1 -0.1829  0.2320  1.2080 -0.4522
# 2  id_002429b5b  ctl_vehicle       24      D1  0.1852 -0.1404 -0.3911  0.1310
# 3  id_00276f245       trt_cp       24      D2  0.4828  0.1955  0.3825  0.4244
# 4  id_0027f1083       trt_cp       48      D1 -0.3979 -1.2680  1.9130  0.2057
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0  1.5500 -0.1644  ...  0.0981  0.7978 -0.1430 -0.2067 -0.2303 -0.1193
# 1 -0.3652 -0.3319  ... -0.1190 -0.1852 -1.0310 -1.3670 -0.3690 -0.5382
# 2 -1.4380  0.2455  ... -0.2261  0.3370 -1.3840  0.8604 -1.9530 -1.0140
# 3 -0.5855 -1.2020  ...  0.1260  0.1570 -0.1784 -1.1200 -0.4325 -0.9005
# 4 -0.5864 -0.0166  ...  0.4965  0.7578 -0.1580  1.0510  0.5742  1.0900
#
#      c-96    c-97    c-98    c-99
# 0  0.0210 -0.0502  0.1510 -0.7750
# ...

# %%
test.describe()
# Out:
#            cp_time          g-0          g-1          g-2          g-3  \
# count  3982.000000  3982.000000  3982.000000  3982.000000  3982.000000
# mean     48.030136     0.197471    -0.063233     0.137516     0.049622
# std      19.414155     1.373476     0.800573     1.066475     0.949972
# min      24.000000    -5.321000    -4.142000    -6.996000    -3.765000
# 25%      24.000000    -0.502725    -0.552975    -0.431800    -0.465350
# 50%      48.000000    -0.060700    -0.027500     0.073400    -0.036450
# 75%      72.000000     0.454650     0.429950     0.641125     0.423150
# max      72.000000    10.000000     4.536000     8.227000    10.000000
#
#                g-4          g-5          g-6          g-7          g-8  ...  \
# count  3982.000000  3982.000000  3982.000000  3982.000000  3982.000000  ...
# mean      0.052434    -0.147852     0.010424    -0.166886    -0.168069  ...
# std       0.994018     1.204934     0.859452     1.088335     1.666240  ...
# ...

# %%
train['dataset'] = 'train'
test['dataset']='test'

# %%
print(train.head(2))
print(test.head(2))
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
#
#       g-4     g-5  ...    c-91    c-92    c-93    c-94    c-95    c-96  \
# 0 -0.1944 -1.0120  ...  0.2584  0.8076  0.5523 -0.1912  0.6584 -0.3981
# 1  1.0190  0.5207  ...  0.7543  0.4708  0.0230  0.2957  0.4899  0.1522
#
#      c-97    c-98    c-99  dataset
# 0  0.2139  0.3801  0.4176    train
# 1  0.1241  0.6077  0.7371    train
#
# [2 rows x 877 columns]
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_0004d9e33  trt_cp       24      D1 -0.5458  0.1306 -0.5135  0.4408
# 1  id_001897cda  trt_cp       72      D1 -0.1829  0.2320  1.2080 -0.4522
#
#       g-4     g-5  ...    c-91   c-92    c-93    c-94    c-95    c-96    c-97  \
# 0  1.5500 -0.1644  ...  0.7978 -0.143 -0.2067 -0.2303 -0.1193  0.0210 -0.0502
# ...

# %%
data = pd.concat([train, test])
data.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-91    c-92    c-93    c-94    c-95    c-96  \
# 0 -0.1944 -1.0120  ...  0.2584  0.8076  0.5523 -0.1912  0.6584 -0.3981
# 1  1.0190  0.5207  ...  0.7543  0.4708  0.0230  0.2957  0.4899  0.1522
# 2 -0.0323  1.2390  ... -0.6297  0.6103  0.0223 -1.3240 -0.3174 -0.6417
# 3  4.0620 -0.8095  ... -0.6441 -5.6300 -1.3780 -0.8632 -1.2880 -1.6210
# 4  1.4180 -0.8244  ...  0.0048  0.6670  1.0690  0.5523 -0.3031  0.1094
#
#      c-97    c-98    c-99  dataset
# 0  0.2139  0.3801  0.4176    train
# ...

# %% [markdown]
# **cp_type feature**

# %%
ctype = data.groupby(['cp_type','dataset'])['sig_id'].count().reset_index()
ctype.columns=['cp_type', 'dataset', 'count']
ctype.head()
# Out:
#        cp_type dataset  count
# 0  ctl_vehicle    test    358
# 1  ctl_vehicle   train   1866
# 2       trt_cp    test   3624
# 3       trt_cp   train  21948

# %%
fig = px.bar(
    ctype, 
    x='cp_type', 
    y="count", 
    color = 'dataset',
    barmode='stack',
    orientation='v', 
    title='Feature cp_type counts', 
    width=500,  
    height=400  
)
fig.show(renderer='svg')

# %% [markdown]
# **cp_time feature**

# %%
cptime = data.groupby(['cp_time', 'dataset'])['sig_id'].count().reset_index()
cptime.columns = ['cp_time', 'dataset', 'count']
cptime.head()
# Out:
#    cp_time dataset  count
# 0       24    test   1300
# 1       24   train   7772
# 2       48    test   1377
# 3       48   train   8250
# 4       72    test   1305

# %%
fig = px.bar(
    cptime, 
    x='cp_time', 
    y="count", 
    color = 'dataset',
    barmode='stack',
    orientation='v', 
    title='Feature cp_type Counts', 
    width=500,  
    height=400  
)
fig.show(renderer='svg')

# %% [markdown]
# **cp_dose feature**

# %%
cpdose = data.groupby(['cp_dose', 'dataset'])['sig_id'].count().reset_index()
cpdose.columns = ['cp_dose', 'dataset', 'count']
cpdose.head()
# Out:
#   cp_dose dataset  count
# 0      D1    test   2027
# 1      D1   train  12147
# 2      D2    test   1955
# 3      D2   train  11667

# %%
fig = px.bar(
    cpdose, 
    x='cp_dose', 
    y="count", 
    color = 'dataset',
    barmode='stack',
    orientation='v', 
    title='Feature cp_dose counts', 
    width=500,
    height=400
)

fig.show(renderer='svg')

# %%
train_columns = train.columns.to_list()
gfeatures = [g for g in train_columns if g.startswith('g-')]
cfeatures = [c for c in train_columns if c.startswith('c-')]
restfeatures = [r for r in train_columns if (r[1]!= '-')]

# %%
print(f"Total number of gene expression data features: {len(gfeatures)}")
print(f"Total number of cell viability data features: {len(cfeatures)}")
print(f"Rest of the features: {len(restfeatures)}" + f", and they are: {restfeatures}")
# Out:
# Total number of gene expression data features: 772
# Total number of cell viability data features: 100
# Rest of the features: 5, and they are: ['sig_id', 'cp_type', 'cp_time', 'cp_dose', 'dataset']
